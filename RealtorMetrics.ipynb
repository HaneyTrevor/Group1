# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import seaborn as sns
from pprint import pprint

# %%
realtor_df = pd.read_csv('RDC_Inventory_Core_Metrics_Zip_History 91910 92110.csv')
realtor_df.head()
# Out:
#    month_date_yyyymm  postal_code         zip_name flag  median_listing_price  \
# 0             202010        91910  chula vista, ca    *              619050.0
# 1             202010        92110    san diego, ca  NaN              650050.0
# 2             202009        92110    san diego, ca  NaN              619050.0
# 3             202009        91910  chula vista, ca    *              604050.0
# 4             202008        91910  chula vista, ca  NaN              610050.0
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                   0.0248                   0.0765                    28
# 1                   0.0501                   0.0934                    44
# 2                   0.0317                   0.0412                    45
# 3                  -0.0098                   0.0401                    23
# 4                  -0.0073                   0.1076                    32
#
# ...

# %%
# Selects the specific columns wanted for metrics
realtor_df[["month_date_yyyymm","postal_code","zip_name","median_listing_price","total_listing_count"]]
# Out:
#      month_date_yyyymm  postal_code         zip_name  median_listing_price  \
# 0               202010        91910  chula vista, ca              619050.0
# 1               202010        92110    san diego, ca              650050.0
# 2               202009        92110    san diego, ca              619050.0
# 3               202009        91910  chula vista, ca              604050.0
# 4               202008        91910  chula vista, ca              610050.0
# ..                 ...          ...              ...                   ...
# 99              201609        92110    san diego, ca              500050.0
# 100             201608        92110    san diego, ca              492500.0
# 101             201608        91910  chula vista, ca              492050.0
# 102             201607        91910  chula vista, ca              490050.0
# 103             201607        92110    san diego, ca              469950.0
#
#      total_listing_count
# 0                    139
# ...

# %%
# Establish alises
zip_code = realtor_df["postal_code"].value_counts()
Median_list = realtor_df["median_listing_price"]
Date = realtor_df["month_date_yyyymm"]
pprint(zip_code)
# Out:
# 92110    52
# 91910    52
# Name: postal_code, dtype: int64

# %%
# Define graph X & Y & limitations
x_axis_data=np.arange(len(Median_list))
y_axis_data=np.arange(len(Date))
tick_locations = [value for value in Date]
plt.xticks(tick_locations, Date, rotation="vertical")

#plt.show
#plt.plot(zip_code.index)
#pprint(zip_code)
# Out:
# ([<matplotlib.axis.XTick at 0x1f83ed8ed48>,
# ...
#  <a list of 104 Text xticklabel objects>)

# %%
for code in zip_code.index:
    pprint(code)
    plt.plot(Date, Median_list)
# Out:
# 92110
# <img src="data:image/png;base64,..." width="1143.7037844978463">
# 91910
